# %% [markdown]
# # Libraries

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
color = sns.color_palette()

# %matplotlib inline

pd.options.mode.chained_assignment = None  # default='warn

# %% [markdown]
# # Loading Data

# %%
order_products_train_df = pd.read_csv("C:/Users/Ruchil/OneDrive/projects/instacart-market-basket-analysis/order_products__train.csv")
order_products_prior_df = pd.read_csv("C:/Users/Ruchil/OneDrive/projects/instacart-market-basket-analysis/order_products__prior.csv")
orders_df = pd.read_csv("C:/Users/Ruchil/OneDrive/projects/instacart-market-basket-analysis/orders.csv")
products_df = pd.read_csv("C:/Users/Ruchil/OneDrive/projects/instacart-market-basket-analysis/products.csv")
aisles_df = pd.read_csv("C:/Users/Ruchil/OneDrive/projects/instacart-market-basket-analysis/aisles.csv")
departments_df = pd.read_csv("C:/Users/Ruchil/OneDrive/projects/instacart-market-basket-analysis/departments.csv")

# %%
orders_df.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
departments_df
# Out:
#     department_id       department
# 0               1           frozen
# 1               2            other
# 2               3           bakery
# 3               4          produce
# 4               5          alcohol
# 5               6    international
# 6               7        beverages
# 7               8             pets
# 8               9  dry goods pasta
# 9              10             bulk
# 10             11    personal care
# 11             12     meat seafood
# 12             13           pantry
# 13             14        breakfast
# 14             15     canned goods
# 15             16       dairy eggs
# 16             17        household
# 17             18           babies
# 18             19           snacks
# 19             20             deli
# 20             21          missing

# %%
aisles_df
# Out:
#      aisle_id                       aisle
# 0           1       prepared soups salads
# 1           2           specialty cheeses
# 2           3         energy granola bars
# 3           4               instant foods
# 4           5  marinades meat preparation
# ..        ...                         ...
# 129       130    hot cereal pancake mixes
# 130       131                   dry pasta
# 131       132                      beauty
# 132       133  muscles joints pain relief
# 133       134  specialty wines champagnes
#
# [134 rows x 2 columns]

# %%
order_products_train_df.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         1       49302                  1          1
# 1         1       11109                  2          1
# 2         1       10246                  3          0
# 3         1       49683                  4          0
# 4         1       43633                  5          1

# %%
order_products_prior_df.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
products_df
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49683       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49684       49685                 En Croute Roast Hazelnut Cranberry
# 49685       49686                                   Artisan Baguette
# 49686       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49687       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id
# 0            61             19
# 1           104             13
# 2            94              7
# ...

# %% [markdown]
# # EDA

# %%
# Plot histograms of features of interest
fig, axes = plt.subplots(2, 2, figsize=(12,10))

ax0 = axes[0,0]
ax0.hist(orders_df.user_id.value_counts(), bins=100)
ax0.set_title('Orders Per User')
ax0.set_xlabel('Orders')
ax0.set_ylabel('Users')

ax1 = axes[0,1]
ax1.hist(orders_df.order_dow, bins=7)
ax1.set_title('Order Day of Week')
ax1.set_xlabel('Day of Week')
ax1.set_ylabel('Orders')

ax2 = axes[1,0]
ax2.hist(orders_df.order_hour_of_day, bins=24)
ax2.set_title('Order Hour of Day')
ax2.set_xlabel('Hour (24-Hour Clock)')
ax2.set_ylabel('Orders')

ax3 = axes[1,1]
ax3.hist(orders_df.days_since_prior_order, bins=30)
ax3.set_title('Days Since Prior Order')
ax3.set_xlabel('Lag in Days')
ax3.set_ylabel('Orders')

plt.tight_layout()
plt.show();

# %%
cnt_srs = orders_df.eval_set.value_counts()

plt.figure(figsize=(12,8))
sns.barplot(cnt_srs.index, cnt_srs.values, alpha=0.8, color=color[1])
plt.ylabel('Number of Occurrences', fontsize=12)
plt.xlabel('Eval set type', fontsize=12)
plt.title('Count of rows in each dataset', fontsize=15)
plt.xticks(rotation='vertical')
plt.show()
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
def get_unique_count(x):
    return len(np.unique(x))

cnt_srs = orders_df.groupby("eval_set")["user_id"].aggregate(get_unique_count)
cnt_srs
# Out:
# eval_set
# prior    206209
# test      75000
# train    131209
# Name: user_id, dtype: int64

# %%
cnt_srs = orders_df.groupby("user_id")["order_number"].aggregate(np.max).reset_index()
cnt_srs = cnt_srs.order_number.value_counts()

plt.figure(figsize=(12,8))
sns.barplot(cnt_srs.index, cnt_srs.values, alpha=0.8, color='lightgreen')
plt.axvline(orders_df.user_id.value_counts().mean(), color='orange', 
            linestyle='--', label='Mean')
plt.axvline(orders_df.user_id.value_counts().median(), color='darkgreen', 
            linestyle='--', label='Median')
plt.ylabel('Number of Occurrences', fontsize=12)
plt.xlabel('Maximum order number', fontsize=12)
plt.title('Orders Per User', fontsize=15)
plt.xticks(rotation='vertical')
plt.legend()
plt.show()
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Print mean and median
print('Mean orders per customer:', orders_df.user_id.value_counts().mean())
print('Median orders per customer:', orders_df.user_id.value_counts().median())
# Out:
# Mean orders per customer: 16.590367054784224
# Median orders per customer: 10.0

# %%
# Visualize orders by day of week
plt.figure(figsize=(12,8))
sns.countplot(x="order_dow", data=orders_df, color='lightblue')
plt.axvline(orders_df.order_dow.mean(), color='orange', 
            linestyle='--', label='Mean')
plt.axvline(orders_df.order_dow.median(), color='darkgreen', 
            linestyle='--', label='Median')
plt.title('Orders Per Day of Week', fontsize=15)
plt.xlabel('Day of Week',fontsize=12)
plt.ylabel('Orders',fontsize=12)
plt.xticks(rotation='vertical')
plt.savefig('orders_per_day.png', dpi=300, pad_inches=0.5)
plt.legend()
plt.show()

# %%
# Print mean and median
print('Mean order day:', orders_df.order_dow.mean())
print('Median order day:', orders_df.order_dow.median())
# Out:
# Mean order day: 2.7762191095626734
# Median order day: 3.0

# %%
plt.figure(figsize=(12,8))
sns.countplot(x="order_hour_of_day", data=orders_df, color='lightblue')
plt.ylabel('Count', fontsize=12)
plt.xlabel('Hour of day', fontsize=12)
plt.xticks(rotation='vertical')
plt.axvline(orders_df.order_hour_of_day.mean(), color='orange', 
            linestyle='--', label='Mean')
plt.axvline(orders_df.order_hour_of_day.median(), color='darkgreen', 
            linestyle='--', label='Median')
plt.title('Orders Per Hour in a Day', fontsize=15)
plt.show()

# %%
# Print mean and median
print('Mean order hour:', orders_df.order_hour_of_day.mean())
print('Median order hour:', orders_df.order_hour_of_day.median())
# Out:
# Mean order hour: 13.45201534134074
# Median order hour: 13.0

# %%
grouped_df = orders_df.groupby(["order_dow", "order_hour_of_day"])["order_number"].aggregate("count").reset_index()
grouped_df = grouped_df.pivot('order_dow', 'order_hour_of_day', 'order_number')

plt.figure(figsize=(12,6))
sns.heatmap(grouped_df,color = 'lightpink')
plt.title("Day of week Vs Hour of day")
plt.ylabel('Day of Week', fontsize=12)
plt.xlabel('Hour of day', fontsize=12)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.countplot(x="days_since_prior_order", data=orders_df, color=color[1])
plt.axvline(orders_df.days_since_prior_order.mean(), color='orange', 
            linestyle='--', label='Mean')
plt.axvline(orders_df.days_since_prior_order.median(), color='darkgreen', 
            linestyle='--', label='Median')
plt.xlabel('Days')
plt.ylabel('Orders')
plt.xticks(rotation='vertical')
plt.title("Days Since Prior Order", fontsize=15)
plt.legend()
sns.despine()
plt.savefig('orders_lags.png', dpi=300, pad_inches=0.5)
plt.show();

# %%
# Print mean and median
print('Mean lag:', orders_df.days_since_prior_order.mean())
print('Median lag:', orders_df.days_since_prior_order.median())
# Out:
# Mean lag: 11.114836226863012
# Median lag: 7.0

# %% [markdown]
# ### ReOrdered Products

# %%
# percentage of re-orders in prior set #
order_products_prior_df.reordered.sum() / order_products_prior_df.shape[0]
# Out:
# 0.5896974667922161

# %%
# percentage of re-orders in train set #
order_products_train_df.reordered.sum() / order_products_train_df.shape[0]
#On an average, about 59% of the products in an order are re-ordered products.
# Out:
# 0.5985944127509629

# %% [markdown]
# ### No ReOrdered Products

# %%
grouped_df = order_products_train_df.groupby("order_id")["add_to_cart_order"].aggregate("max").reset_index()
cnt_srs = grouped_df.add_to_cart_order.value_counts()

plt.figure(figsize=(12,8))
sns.barplot(cnt_srs.index, cnt_srs.values, alpha=0.8,color=color[1])
plt.ylabel('Occurrences', fontsize=12)
plt.xlabel('Products in an order', fontsize=12)
plt.title('Number of Products in an order ',fontsize= 15)
plt.show()
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Plot histogram of reorder rates per order
plt.hist(order_products_train_df.groupby('order_id')['reordered'].mean());

# %%
#merge these product details with the order_prior details.
order_products_prior_df = pd.merge(order_products_prior_df, products_df, on='product_id', how='left')
order_products_prior_df = pd.merge(order_products_prior_df, aisles_df, on='aisle_id', how='left')
order_products_prior_df = pd.merge(order_products_prior_df, departments_df, on='department_id', how='left')
order_products_prior_df.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered           product_name  \
# 0         2       33120                  1          1     Organic Egg Whites
# 1         2       28985                  2          1  Michigan Organic Kale
# 2         2        9327                  3          0          Garlic Powder
# 3         2       45918                  4          1         Coconut Butter
# 4         2       30035                  5          0      Natural Sweetener
#
#    aisle_id  department_id               aisle  department
# 0        86             16                eggs  dairy eggs
# 1        83              4    fresh vegetables     produce
# 2       104             13   spices seasonings      pantry
# 3        19             13       oils vinegars      pantry
# 4        17             13  baking ingredients      pantry

# %%
cnt_srs = order_products_prior_df['product_name'].value_counts().reset_index().head(20)
cnt_srs.columns = ['product_name', 'frequency_count']
cnt_srs
# Out:
#                 product_name  frequency_count
# 0                     Banana           472565
# 1     Bag of Organic Bananas           379450
# 2       Organic Strawberries           264683
# 3       Organic Baby Spinach           241921
# 4       Organic Hass Avocado           213584
# 5            Organic Avocado           176815
# 6                Large Lemon           152657
# 7               Strawberries           142951
# 8                      Limes           140627
# 9         Organic Whole Milk           137905
# 10       Organic Raspberries           137057
# 11      Organic Yellow Onion           113426
# 12            Organic Garlic           109778
# 13          Organic Zucchini           104823
# 14       Organic Blueberries           100060
# 15            Cucumber Kirby            97315
# 16        Organic Fuji Apple            89632
# 17             Organic Lemon            87746
# 18  Apple Honeycrisp Organic            85020
# ...

# %%
cnt_srs = order_products_prior_df['aisle'].value_counts().head(20)
plt.figure(figsize=(12,8))
sns.barplot(cnt_srs.index, cnt_srs.values, alpha=0.8, color=color[2])
plt.ylabel('Number of Occurrences', fontsize=12)
plt.xlabel('Aisle', fontsize=12)
plt.xticks(rotation='vertical')
ply.title('Most Popular Aisles')
plt.show()
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-70-eef5e468433b> in <module>
#       5 plt.xlabel('Aisle', fontsize=12)
#       6 plt.xticks(rotation='vertical')
# ----> 7 ply.title('Most Popular Aisles')
#       8 plt.show()
#
# NameError: name 'ply' is not defined

# %% [markdown]
# ### Department distributions

# %%
plt.figure(figsize=(10,10))
temp_series = order_products_prior_df['department'].value_counts()
labels = (np.array(temp_series.index))
sizes = (np.array((temp_series / temp_series.sum())*100))
plt.pie(sizes, labels=labels, 
        autopct='%1.1f%%', startangle=200)
plt.title("Departments distribution", fontsize=15)
plt.show()

# %%
grouped_df = order_products_prior_df.groupby(["department"])["reordered"].aggregate("mean").reset_index()

plt.figure(figsize=(12,8))
sns.pointplot(grouped_df['department'].values, grouped_df['reordered'].values, alpha=0.8, color=color[1])
plt.ylabel('Reorder ratio', fontsize=12)
plt.xlabel('Department', fontsize=12)
plt.title("Department wise reorder ratio", fontsize=15)
plt.xticks(rotation='vertical')
plt.show()
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
order_products_prior_df = order_products_prior_df[0:300000]
a1 = pd.merge(order_products_train_df,products_df, on = ['product_id','product_id'])
b1 = pd.merge(a1,orders_df,on=['order_id','order_id'])
mt = pd.merge(b1,aisles_df,on=['aisle_id','aisle_id'])
mt.head(10)
# Out:
#    order_id  product_id  add_to_cart_order  reordered  \
# 0         1       49302                  1          1
# 1    816049       49302                  7          1
# 2   1242203       49302                  1          1
# 3   1383349       49302                 11          1
# 4   1787378       49302                  8          0
# 5   2445303       49302                  2          1
# 6   2853065       49302                 12          1
# 7   3231517       49302                  6          1
# 8     68474        6104                  5          1
# 9     78197       45521                  4          1
#
#                      product_name  aisle_id  department_id  user_id eval_set  \
# 0                Bulgarian Yogurt       120             16   112108    train
# 1                Bulgarian Yogurt       120             16    47901    train
# 2                Bulgarian Yogurt       120             16     2993    train
# ...

# %%
cust_prod = pd.crosstab(mt['user_id'], mt['aisle'])
cust_prod.head(10)
# Out:
# aisle    air fresheners candles  asian foods  baby accessories  \
# user_id
# 1                             0            0                 0
# 2                             0            0                 0
# 5                             1            2                 0
# 7                             0            0                 0
# 8                             0            0                 0
# 9                             0            0                 0
# 10                            0            0                 0
# 13                            0            0                 0
# 14                            0            0                 0
# 17                            0            0                 0
#
# aisle    baby bath body care  baby food formula  bakery desserts  \
# user_id
# 1                          0                  0                0
# 2                          0                  0                0
# ...

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=6)
pca.fit(cust_prod)
pca_samples = pca.transform(cust_prod)

# %%
ps = pd.DataFrame(pca_samples)
ps.head()
# Out:
#           0         1         2         3         4         5
# 0 -1.585968 -0.068665  1.013506 -0.235297  0.354048 -0.094223
# 1  1.941122  5.166711 -1.604424 -0.862830  2.860253 -0.724603
# 2  0.074848 -0.008703 -0.265351  1.375275 -0.590862  0.088461
# 3 -1.172812  0.391134 -0.402275 -0.261639  0.208914 -0.194204
# 4  6.420225 -4.774948 -0.290903 -0.606782 -0.416352 -0.000680

# %%
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import proj3d
tocluster = pd.DataFrame(ps[[4,1]])
print (tocluster.shape)
print (tocluster.head())

fig = plt.figure(figsize=(8,8))
plt.plot(tocluster[4], tocluster[1], 'o', markersize=2, color='blue', alpha=0.5, label='class1')

plt.xlabel('x_values')
plt.ylabel('y_values')
plt.legend()
plt.show()
# Out:
# (131209, 2)
#           4         1
# 0  0.354048 -0.068665
# 1  2.860253  5.166711
# 2 -0.590862 -0.008703
# 3  0.208914  0.391134
# 4 -0.416352 -4.774948

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

clusterer = KMeans(n_clusters=4,random_state=42).fit(tocluster)
centers = clusterer.cluster_centers_
c_preds = clusterer.predict(tocluster)
print(centers)
# Out:
# [[-0.21529919  1.88496427]
#  [-0.22606135 -0.29259928]
#  [ 1.10850464  0.21356444]
#  [ 0.01354043 -2.10783639]]

# %%
import matplotlib
fig = plt.figure(figsize=(8,8))
colors = ['orange','blue','purple','green']
colored = [colors[k] for k in c_preds]
print (colored[0:10])
plt.scatter(tocluster[4],tocluster[1],  color = colored)
for ci,c in enumerate(centers):
    plt.plot(c[0], c[1], 'o', markersize=8, color='red', alpha=0.9, label=''+str(ci))

plt.xlabel('x_values')
plt.ylabel('y_values')
plt.legend()
plt.show()
# Out:
# ['blue', 'orange', 'blue', 'blue', 'green', 'orange', 'blue', 'blue', 'blue', 'blue']

# %%
clust_prod = cust_prod.copy()
clust_prod['cluster'] = c_preds

clust_prod.head(10)
# Out:
# aisle    air fresheners candles  asian foods  baby accessories  \
# user_id
# 1                             0            0                 0
# 2                             0            0                 0
# 5                             1            2                 0
# 7                             0            0                 0
# 8                             0            0                 0
# 9                             0            0                 0
# 10                            0            0                 0
# 13                            0            0                 0
# 14                            0            0                 0
# 17                            0            0                 0
#
# aisle    baby bath body care  baby food formula  bakery desserts  \
# user_id
# 1                          0                  0                0
# 2                          0                  0                0
# ...

# %%
print (clust_prod.shape)
f,arr = plt.subplots(2,2,sharex=True,figsize=(15,15))

c1_count = len(clust_prod[clust_prod['cluster']==0])

c0 = clust_prod[clust_prod['cluster']==0].drop('cluster',axis=1).mean()
arr[0,0].bar(range(len(clust_prod.drop('cluster',axis=1).columns)),c0)
c1 = clust_prod[clust_prod['cluster']==1].drop('cluster',axis=1).mean()
arr[0,1].bar(range(len(clust_prod.drop('cluster',axis=1).columns)),c1)
c2 = clust_prod[clust_prod['cluster']==2].drop('cluster',axis=1).mean()
arr[1,0].bar(range(len(clust_prod.drop('cluster',axis=1).columns)),c2)
c3 = clust_prod[clust_prod['cluster']==3].drop('cluster',axis=1).mean()
arr[1,1].bar(range(len(clust_prod.drop('cluster',axis=1).columns)),c3)
plt.show()
# Out:
# (131209, 135)

# %%
c0.sort_values(ascending=False)[0:10]
# Out:
# aisle
# fresh fruits                     3.066940
# packaged vegetables fruits       1.108374
# yogurt                           1.045498
# fresh vegetables                 0.868193
# packaged cheese                  0.398739
# milk                             0.389241
# water seltzer sparkling water    0.285596
# soy lactosefree                  0.282900
# chips pretzels                   0.268342
# bread                            0.259591
# dtype: float64

# %%
c1.sort_values(ascending=False)[0:10]
# Out:
# aisle
# fresh vegetables                 0.725196
# fresh fruits                     0.593996
# packaged vegetables fruits       0.456870
# yogurt                           0.278884
# milk                             0.183669
# water seltzer sparkling water    0.177407
# soy lactosefree                  0.155617
# packaged cheese                  0.146122
# frozen produce                   0.124318
# refrigerated                     0.118029
# dtype: float64

# %%
c2.sort_values(ascending=False)[0:10]
# Out:
# aisle
# fresh fruits                     1.112600
# fresh vegetables                 0.948015
# packaged cheese                  0.832318
# chips pretzels                   0.794700
# water seltzer sparkling water    0.700883
# frozen meals                     0.469032
# packaged vegetables fruits       0.405879
# ice cream ice                    0.383440
# crackers                         0.378465
# milk                             0.349223
# dtype: float64

# %%
c3.sort_values(ascending=False)[0:10]
# Out:
# aisle
# fresh vegetables              4.347304
# fresh fruits                  0.798966
# packaged vegetables fruits    0.749220
# fresh herbs                   0.382977
# packaged cheese               0.368145
# yogurt                        0.255267
# canned jarred vegetables      0.244999
# soy lactosefree               0.237012
# frozen produce                0.224082
# soup broth bouillon           0.213281
# dtype: float64

# %% [markdown]
# A first analysis of the clusters confirm the initial hypothesis that:
#
# fresh fruits
# fresh vegetables
# packaged vegetables fruits
# yogurt
# packaged cheese
# milk
# water seltzer sparkling water
# chips pretzels

# %%
from IPython.display import display, HTML
cluster_means = [[c0['fresh fruits'],c0['fresh vegetables'],c0['packaged vegetables fruits'], c0['yogurt'], c0['packaged cheese'], c0['milk'],c0['water seltzer sparkling water'],c0['chips pretzels']],
                 [c1['fresh fruits'],c1['fresh vegetables'],c1['packaged vegetables fruits'], c1['yogurt'], c1['packaged cheese'], c1['milk'],c1['water seltzer sparkling water'],c1['chips pretzels']],
                 [c2['fresh fruits'],c2['fresh vegetables'],c2['packaged vegetables fruits'], c2['yogurt'], c2['packaged cheese'], c2['milk'],c2['water seltzer sparkling water'],c2['chips pretzels']],
                 [c3['fresh fruits'],c3['fresh vegetables'],c3['packaged vegetables fruits'], c3['yogurt'], c3['packaged cheese'], c3['milk'],c3['water seltzer sparkling water'],c3['chips pretzels']]]
cluster_means = pd.DataFrame(cluster_means, columns = ['fresh fruits','fresh vegetables','packaged vegetables fruits','yogurt','packaged cheese','milk','water seltzer sparkling water','chips pretzels'])
HTML(cluster_means.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>fresh fruits</th>
#       <th>fresh vegetables</th>
#       <th>packaged vegetables fruits</th>
#       <th>yogurt</th>
#       <th>packaged cheese</th>
#       <th>milk</th>
#       <th>water seltzer sparkling water</th>
#       <th>chips pretzels</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>3.066940</td>
#       <td>0.868193</td>
#       <td>1.108374</td>
#       <td>1.045498</td>
#       <td>0.398739</td>
#       <td>0.389241</td>
#       <td>0.285596</td>
#       <td>0.268342</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.593996</td>
#       <td>0.725196</td>
#       <td>0.456870</td>
#       <td>0.278884</td>
#       <td>0.146122</td>
#       <td>0.183669</td>
#       <td>0.177407</td>
#       <td>0.093222</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1.112600</td>
#       <td>0.948015</td>
# ...

# %%
cluster_perc = cluster_means.iloc[:, :].apply(lambda x: (x / x.sum())*100,axis=1)
HTML(cluster_perc.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>fresh fruits</th>
#       <th>fresh vegetables</th>
#       <th>packaged vegetables fruits</th>
#       <th>yogurt</th>
#       <th>packaged cheese</th>
#       <th>milk</th>
#       <th>water seltzer sparkling water</th>
#       <th>chips pretzels</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>41.272667</td>
#       <td>11.683513</td>
#       <td>14.915693</td>
#       <td>14.069555</td>
#       <td>5.365944</td>
#       <td>5.238130</td>
#       <td>3.843342</td>
#       <td>3.611156</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>22.369642</td>
#       <td>27.310581</td>
#       <td>17.205544</td>
#       <td>10.502665</td>
#       <td>5.502893</td>
#       <td>6.916909</td>
#       <td>6.681071</td>
#       <td>3.510694</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>20.427452</td>
# ...

# %%
c0.sort_values(ascending=False)[10:15]
# Out:
# aisle
# frozen produce         0.256854
# refrigerated           0.244577
# energy granola bars    0.216125
# crackers               0.204512
# eggs                   0.200655
# dtype: float64

# %%
c1.sort_values(ascending=False)[10:15]
# Out:
# aisle
# bread               0.117490
# ice cream ice       0.115282
# eggs                0.113598
# packaged produce    0.103390
# soft drinks         0.099457
# dtype: float64

# %%
c2.sort_values(ascending=False)[10:15]
# Out:
# aisle
# refrigerated           0.336735
# energy granola bars    0.320439
# bread                  0.319779
# yogurt                 0.302975
# baby food formula      0.284394
# dtype: float64

# %%
c3.sort_values(ascending=False)[10:15]
# Out:
# aisle
# water seltzer sparkling water    0.209325
# milk                             0.208565
# eggs                             0.203545
# bread                            0.178976
# canned meals beans               0.178063
# dtype: float64
